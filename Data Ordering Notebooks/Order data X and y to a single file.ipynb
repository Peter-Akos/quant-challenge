# %%
import pandas as pd
import numpy as np
import tqdm
from utils import get_data_from_station, get_stations, unite_stations, columns, county_names, dates, metrics, fill_missing

# %%
final_dataframe = pd.DataFrame(columns=columns)
for county in tqdm.tqdm(county_names):
    stations = get_stations(county)
    stations_data = []
    for station in stations:
        curr = get_data_from_station(station)
        stations_data.append(curr)
    current_data = unite_stations(stations_data, county)
    current_dataframe = pd.DataFrame(index=current_data.keys(), data=current_data.values(), columns=columns)
    final_dataframe = pd.concat([final_dataframe, current_dataframe])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 87/87 [03:16<00:00,  2.26s/it]

# %%
# final_dataframe.to_csv('final_data_nonnull.csv')

# %%
final_dataframe
# Out:
#                     01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 1973-Pope County   -14.300000     -22.00  -9.000000         NaN  -8.400000
# 1974-Pope County          NaN        NaN        NaN         NaN        NaN
# 1975-Pope County          NaN        NaN        NaN         NaN  -3.600000
# 1976-Pope County    -3.400000      -4.90  -2.700000         NaN        NaN
# 1977-Pope County          NaN        NaN        NaN         NaN        NaN
# ...                       ...        ...        ...         ...        ...
# 2011-Waseca County -16.200000     -18.50 -14.500000         NaN -12.700000
# 2012-Waseca County  -3.166667      -7.00   1.000000         NaN  -9.050000
# 2013-Waseca County -15.025000     -23.25  -7.500000         NaN  -8.475000
# 2014-Waseca County -18.400000     -21.00 -16.333333         NaN -20.933333
# 2015-Waseca County  -6.333333     -13.00  -0.666667         NaN  -7.300000
#
#                     01-02-min  01-02-max  01-02-prec  01-03-avg  01-03-min  \
# 1973-Pope County   -17.000000      -2.00         NaN  -8.800000 -17.000000
# 1974-Pope County          NaN        NaN         NaN        NaN        NaN
# 1975-Pope County    -8.800000      -0.50         NaN  -6.900000 -14.900000
# 1976-Pope County          NaN        NaN         NaN -20.600000 -25.500000
# 1977-Pope County          NaN        NaN         NaN        NaN        NaN
# ...                       ...        ...         ...        ...        ...
# 2011-Waseca County -19.000000      -6.00         NaN  -8.200000 -17.000000
# 2012-Waseca County -14.000000      -6.50         NaN  -6.633333 -12.666667
# 2013-Waseca County -12.000000      -3.25         NaN -10.750000 -13.500000
# 2014-Waseca County -26.666667     -17.00         NaN -12.166667 -26.333333
# 2015-Waseca County -14.500000      -2.75         NaN  -3.466667  -9.666667
#
#                     ...  09-27-max  09-27-prec  09-28-avg  09-28-min  \
# 1973-Pope County    ...        NaN         NaN  14.800000  10.000000
# 1974-Pope County    ...        NaN         NaN        NaN        NaN
# 1975-Pope County    ...      17.80         NaN  10.000000   7.800000
# 1976-Pope County    ...      12.20         NaN        NaN        NaN
# 1977-Pope County    ...      18.30         NaN  13.100000   8.300000
# ...                 ...        ...         ...        ...        ...
# 2011-Waseca County  ...      18.00         NaN  17.725000  11.250000
# 2012-Waseca County  ...      20.50         NaN  14.033333   4.666667
# 2013-Waseca County  ...      29.25         NaN  16.200000   8.666667
# 2014-Waseca County  ...      26.75         NaN  19.566667  12.666667
# 2015-Waseca County  ...      27.50         NaN  19.825000  16.000000
#
#                     09-28-max  09-28-prec  09-30-avg  09-30-min  09-30-max  \
# 1973-Pope County    23.300000         NaN        NaN        NaN        NaN
# 1974-Pope County          NaN         NaN        NaN        NaN        NaN
# 1975-Pope County    11.700000         NaN        NaN        NaN        NaN
# 1976-Pope County          NaN         NaN        NaN        NaN        NaN
# 1977-Pope County    18.900000         NaN        NaN        NaN        NaN
# ...                       ...         ...        ...        ...        ...
# 2011-Waseca County  26.250000         NaN  11.900000   6.750000  17.000000
# 2012-Waseca County  24.666667         NaN  16.533333   6.666667  26.666667
# 2013-Waseca County  22.000000         NaN  18.500000  12.333333  25.666667
# 2014-Waseca County  26.666667         NaN  10.300000   5.750000  16.000000
# 2015-Waseca County  24.000000         NaN  10.666667   4.666667  17.000000
#
#                     09-30-prec
# 1973-Pope County           NaN
# 1974-Pope County           NaN
# 1975-Pope County           NaN
# 1976-Pope County           NaN
# 1977-Pope County           NaN
# ...                        ...
# 2011-Waseca County         NaN
# 2012-Waseca County         NaN
# 2013-Waseca County         NaN
# 2014-Waseca County         NaN
# 2015-Waseca County         NaN
#
# [3214 rows x 888 columns]

# %%
X = final_dataframe[final_dataframe.isna().sum(axis=1) < 444]

# %%
X
# Out:
#                     01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 1993-Pope County   -23.500000     -28.90 -16.700000         NaN        NaN
# 1999-Pope County   -19.300000     -23.00 -16.000000         NaN -12.900000
# 2000-Pope County    -5.400000      -7.80  -2.800000         NaN  -3.800000
# 2001-Pope County   -21.200000     -26.70 -15.000000         NaN -12.100000
# 2002-Pope County   -15.000000     -18.90 -12.800000         NaN -17.300000
# ...                       ...        ...        ...         ...        ...
# 2011-Waseca County -16.200000     -18.50 -14.500000         NaN -12.700000
# 2012-Waseca County  -3.166667      -7.00   1.000000         NaN  -9.050000
# 2013-Waseca County -15.025000     -23.25  -7.500000         NaN  -8.475000
# 2014-Waseca County -18.400000     -21.00 -16.333333         NaN -20.933333
# 2015-Waseca County  -6.333333     -13.00  -0.666667         NaN  -7.300000
#
#                     01-02-min  01-02-max  01-02-prec  01-03-avg  01-03-min  \
# 1993-Pope County          NaN        NaN         NaN  -9.300000 -17.800000
# 1999-Pope County   -16.000000     -11.00         NaN        NaN        NaN
# 2000-Pope County    -5.600000      -2.80         NaN  -5.800000 -13.900000
# 2001-Pope County   -18.900000      -5.00         NaN  -4.800000  -5.600000
# 2002-Pope County   -21.700000     -12.80         NaN  -9.500000 -15.000000
# ...                       ...        ...         ...        ...        ...
# 2011-Waseca County -19.000000      -6.00         NaN  -8.200000 -17.000000
# 2012-Waseca County -14.000000      -6.50         NaN  -6.633333 -12.666667
# 2013-Waseca County -12.000000      -3.25         NaN -10.750000 -13.500000
# 2014-Waseca County -26.666667     -17.00         NaN -12.166667 -26.333333
# 2015-Waseca County -14.500000      -2.75         NaN  -3.466667  -9.666667
#
#                     ...  09-27-max  09-27-prec  09-28-avg  09-28-min  \
# 1993-Pope County    ...      15.50         NaN        NaN        NaN
# 1999-Pope County    ...      13.90         NaN   8.700000   3.900000
# 2000-Pope County    ...      15.60         NaN  14.500000   3.300000
# 2001-Pope County    ...      22.20         NaN  12.800000   6.100000
# 2002-Pope County    ...      18.30         NaN   9.200000   6.700000
# ...                 ...        ...         ...        ...        ...
# 2011-Waseca County  ...      18.00         NaN  17.725000  11.250000
# 2012-Waseca County  ...      20.50         NaN  14.033333   4.666667
# 2013-Waseca County  ...      29.25         NaN  16.200000   8.666667
# 2014-Waseca County  ...      26.75         NaN  19.566667  12.666667
# 2015-Waseca County  ...      27.50         NaN  19.825000  16.000000
#
#                     09-28-max  09-28-prec  09-30-avg  09-30-min  09-30-max  \
# 1993-Pope County          NaN         NaN  12.000000   5.000000  21.100000
# 1999-Pope County    13.900000         NaN   8.800000   5.000000  12.200000
# 2000-Pope County    27.200000         NaN  16.700000   7.800000  26.700000
# 2001-Pope County    20.600000         NaN  16.000000  11.100000  22.800000
# 2002-Pope County    11.100000         NaN  17.600000  12.200000  26.700000
# ...                       ...         ...        ...        ...        ...
# 2011-Waseca County  26.250000         NaN  11.900000   6.750000  17.000000
# 2012-Waseca County  24.666667         NaN  16.533333   6.666667  26.666667
# 2013-Waseca County  22.000000         NaN  18.500000  12.333333  25.666667
# 2014-Waseca County  26.666667         NaN  10.300000   5.750000  16.000000
# 2015-Waseca County  24.000000         NaN  10.666667   4.666667  17.000000
#
#                     09-30-prec
# 1993-Pope County           NaN
# 1999-Pope County           NaN
# 2000-Pope County           NaN
# 2001-Pope County           NaN
# 2002-Pope County           NaN
# ...                        ...
# 2011-Waseca County         NaN
# 2012-Waseca County         NaN
# 2013-Waseca County         NaN
# 2014-Waseca County         NaN
# 2015-Waseca County         NaN
#
# [2721 rows x 888 columns]

# %%
X.to_csv('weather-0101-0930.csv')

# %%
final_dataframe.isna().sum().sum()
# Out:
# 516422

# %%
y = pd.read_csv('../data/final_y.csv', index_col=0)

# %%
y
# Out:
#                             County  BU / ACRE
# new_index
# 1950-Aitkin County          AITKIN       15.0
# 1950-Anoka County            ANOKA       28.0
# 1950-Becker County          BECKER       26.0
# 1950-Beltrami County      BELTRAMI       21.0
# 1950-Benton County          BENTON       21.0
# ...                            ...        ...
# 2021-Waseca County          WASECA      213.7
# 2021-Washington County  WASHINGTON      153.6
# 2021-Watonwan County      WATONWAN      210.1
# 2021-Wilkin County          WILKIN      151.5
# 2021-Wright County          WRIGHT      144.8
#
# [5119 rows x 2 columns]

# %%
y_index = y.index.to_list()
x_index = X.index.to_list()

# %%
common = []
for t in x_index:
    if t in y_index:
        common.append(t)

# %%
len(common)
# Out:
# 1449

# %%
[x for x in x_index if x not in common]
# Out:
# ['2022-Nicollet County',
#  '2017-Aitkin County',
#  '2019-Aitkin County',
#  '2022-Aitkin County',
#  '2006-Aitkin County',
#  '2008-Aitkin County',
#  '2009-Aitkin County',
#  '2011-Aitkin County',
#  '2012-Aitkin County',
#  '2015-Aitkin County',
#  '2018-Norman County',
#  '2019-Norman County',
#  '2022-Norman County',
#  '2022-Hennepin County',
#  '1948-Saint Louis County',
#  '1949-Saint Louis County',
#  '1950-Saint Louis County',
#  '1951-Saint Louis County',
#  '1952-Saint Louis County',
#  '1953-Saint Louis County',
#  '1954-Saint Louis County',
#  '1955-Saint Louis County',
#  '1956-Saint Louis County',
#  '1957-Saint Louis County',
#  '1958-Saint Louis County',
#  '1959-Saint Louis County',
#  '1960-Saint Louis County',
#  '1961-Saint Louis County',
#  '1962-Saint Louis County',
#  '1963-Saint Louis County',
#  '1964-Saint Louis County',
#  '1965-Saint Louis County',
#  '1966-Saint Louis County',
#  '1967-Saint Louis County',
#  '1968-Saint Louis County',
#  '1969-Saint Louis County',
#  '1970-Saint Louis County',
#  '1971-Saint Louis County',
#  '1972-Saint Louis County',
#  '1973-Saint Louis County',
#  '1974-Saint Louis County',
#  '1975-Saint Louis County',
#  '1976-Saint Louis County',
#  '1977-Saint Louis County',
#  '1978-Saint Louis County',
#  '1979-Saint Louis County',
#  '1980-Saint Louis County',
#  '1981-Saint Louis County',
#  '1982-Saint Louis County',
#  '1983-Saint Louis County',
#  '1984-Saint Louis County',
#  '1985-Saint Louis County',
#  '1986-Saint Louis County',
#  '1987-Saint Louis County',
#  '1988-Saint Louis County',
#  '1989-Saint Louis County',
#  '1990-Saint Louis County',
#  '1991-Saint Louis County',
#  '1992-Saint Louis County',
#  '1993-Saint Louis County',
#  '1994-Saint Louis County',
#  '1995-Saint Louis County',
#  '1996-Saint Louis County',
#  '1997-Saint Louis County',
#  '1998-Saint Louis County',
#  '1999-Saint Louis County',
#  '2000-Saint Louis County',
#  '2001-Saint Louis County',
#  '2002-Saint Louis County',
#  '2003-Saint Louis County',
#  '2004-Saint Louis County',
#  '2005-Saint Louis County',
#  '2006-Saint Louis County',
#  '2007-Saint Louis County',
#  '2008-Saint Louis County',
#  '2009-Saint Louis County',
#  '2010-Saint Louis County',
#  '2011-Saint Louis County',
#  '2012-Saint Louis County',
#  '2013-Saint Louis County',
#  '2014-Saint Louis County',
#  '2015-Saint Louis County',
#  '2016-Saint Louis County',
#  '2017-Saint Louis County',
#  '2018-Saint Louis County',
#  '2019-Saint Louis County',
#  '2020-Saint Louis County',
#  '2021-Saint Louis County',
#  '2022-Saint Louis County',
#  '2018-Mille Lacs County',
#  '2022-Mille Lacs County',
#  '2018-Wright County',
#  '2019-Wright County',
#  '2022-Wright County',
#  '2021-Yellow Medicine County',
#  '2022-Yellow Medicine County',
#  '2017-Polk County',
#  '2018-Polk County',
#  '2019-Polk County',
#  '2022-Polk County',
#  '2008-Polk County',
#  '1896-Beltrami County',
#  '1897-Beltrami County',
#  '1899-Beltrami County',
#  '1900-Beltrami County',
#  '1901-Beltrami County',
#  '1902-Beltrami County',
#  '1903-Beltrami County',
#  '1904-Beltrami County',
#  '1905-Beltrami County',
#  '1906-Beltrami County',
#  '1912-Beltrami County',
#  '1913-Beltrami County',
#  '1914-Beltrami County',
#  '1915-Beltrami County',
#  '1916-Beltrami County',
#  '1917-Beltrami County',
#  '1918-Beltrami County',
#  '1919-Beltrami County',
#  '1920-Beltrami County',
#  '1922-Beltrami County',
#  '1923-Beltrami County',
#  '1924-Beltrami County',
#  '1925-Beltrami County',
#  '1926-Beltrami County',
#  '1927-Beltrami County',
#  '1928-Beltrami County',
#  '1929-Beltrami County',
#  '1930-Beltrami County',
#  '1931-Beltrami County',
#  '1932-Beltrami County',
#  '1933-Beltrami County',
#  '1934-Beltrami County',
#  '1935-Beltrami County',
#  '1936-Beltrami County',
#  '1937-Beltrami County',
#  '1938-Beltrami County',
#  '1939-Beltrami County',
#  '1940-Beltrami County',
#  '1941-Beltrami County',
#  '1942-Beltrami County',
#  '1943-Beltrami County',
#  '1944-Beltrami County',
#  '1945-Beltrami County',
#  '1946-Beltrami County',
#  '1947-Beltrami County',
#  '1948-Beltrami County',
#  '1949-Beltrami County',
#  '1957-Beltrami County',
#  '1958-Beltrami County',
#  '1959-Beltrami County',
#  '1965-Beltrami County',
#  '1993-Beltrami County',
#  '2004-Beltrami County',
#  '2006-Beltrami County',
#  '2007-Beltrami County',
#  '2008-Beltrami County',
#  '2009-Beltrami County',
#  '2010-Beltrami County',
#  '2011-Beltrami County',
#  '2012-Beltrami County',
#  '2014-Beltrami County',
#  '2015-Beltrami County',
#  '2017-Beltrami County',
#  '2018-Beltrami County',
#  '2019-Beltrami County',
#  '2022-Beltrami County',
#  '2018-Wilkin County',
#  '2019-Wilkin County',
#  '2022-Wilkin County',
#  '2016-Lake County',
#  '2017-Lake County',
#  '2018-Lake County',
#  '2019-Lake County',
#  '2020-Lake County',
#  '2021-Lake County',
#  '2022-Lake County',
#  '2006-Lake County',
#  '2007-Lake County',
#  '2008-Lake County',
#  '2009-Lake County',
#  '2010-Lake County',
#  '2011-Lake County',
#  '2012-Lake County',
#  '2013-Lake County',
#  '2014-Lake County',
#  '2015-Lake County',
#  '2022-Nobles County',
#  '2022-Steele County',
#  '2018-Crow Wing County',
#  '2019-Crow Wing County',
#  '2022-Crow Wing County',
#  '2008-Crow Wing County',
#  '2012-Crow Wing County',
#  '2013-Crow Wing County',
#  '2014-Crow Wing County',
#  '2022-Sibley County',
#  '2018-Douglas County',
#  '2019-Douglas County',
#  '2022-Douglas County',
#  '1940-Stearns County',
#  '1941-Stearns County',
#  '1942-Stearns County',
#  '1943-Stearns County',
#  '1944-Stearns County',
#  '1945-Stearns County',
#  '1946-Stearns County',
#  '1947-Stearns County',
#  '1948-Stearns County',
#  '1949-Stearns County',
#  '2022-Stearns County',
#  '2022-Lyon County',
#  '2022-Morrison County',
#  '2022-Watonwan County',
#  '2022-Carver County',
#  '2016-Isanti County',
#  '2022-Isanti County',
#  '2016-Winona County',
#  '2017-Winona County',
#  '2018-Winona County',
#  '2019-Winona County',
#  '2020-Winona County',
#  '2021-Winona County',
#  '2022-Winona County',
#  '2006-Winona County',
#  '2009-Winona County',
#  '2010-Winona County',
#  '2011-Winona County',
#  '2012-Winona County',
#  '2013-Winona County',
#  '2014-Winona County',
#  '2015-Winona County',
#  '2022-Renville County',
#  '2022-Pope County',
#  '2022-Cottonwood County',
#  '2016-Dodge County',
#  '2017-Dodge County',
#  '2018-Dodge County',
#  '2019-Dodge County',
#  '2020-Dodge County',
#  '2021-Dodge County',
#  '2022-Dodge County',
#  '2006-Dodge County',
#  '2007-Dodge County',
#  '2008-Dodge County',
#  '2009-Dodge County',
#  '2010-Dodge County',
#  '2011-Dodge County',
#  '2012-Dodge County',
#  '2013-Dodge County',
#  '2014-Dodge County',
#  '2015-Dodge County',
#  '2022-Le Sueur County',
#  '2021-Swift County',
#  '2022-Swift County',
#  '2016-Cook County',
#  '2017-Cook County',
#  '2018-Cook County',
#  '2019-Cook County',
#  '2020-Cook County',
#  '2021-Cook County',
#  '2022-Cook County',
#  '2006-Cook County',
#  '2007-Cook County',
#  '2008-Cook County',
#  '2009-Cook County',
#  '2010-Cook County',
#  '2011-Cook County',
#  '2012-Cook County',
#  '2013-Cook County',
#  '2014-Cook County',
#  '2015-Cook County',
#  '2022-Chisago County',
#  '2022-Brown County',
#  '2018-Scott County',
#  '2019-Scott County',
#  '2022-Scott County',
#  '2022-Waseca County',
#  '2022-Wadena County',
#  '2008-Becker County',
#  '2009-Becker County',
#  '2015-Becker County',
#  '2017-Becker County',
#  '2022-Becker County',
#  '2018-Grant County',
#  '2022-Grant County',
#  '2022-Otter Tail County',
#  '2019-Kandiyohi County',
#  '2021-Kandiyohi County',
#  '2022-Kandiyohi County',
#  '1940-Sherburne County',
#  '1941-Sherburne County',
#  '1942-Sherburne County',
#  '1943-Sherburne County',
#  '1944-Sherburne County',
#  '1945-Sherburne County',
#  '1946-Sherburne County',
#  '1947-Sherburne County',
#  '1948-Sherburne County',
#  '1949-Sherburne County',
#  '2018-Sherburne County',
#  '2022-Sherburne County',
#  '2022-Traverse County',
#  '2022-Rock County',
#  '2016-Mower County',
#  '2017-Mower County',
#  '2018-Mower County',
#  '2019-Mower County',
#  '2020-Mower County',
#  '2021-Mower County',
#  '2022-Mower County',
#  '2006-Mower County',
#  '2007-Mower County',
#  '2008-Mower County',
#  '2009-Mower County',
#  '2010-Mower County',
#  '2011-Mower County',
#  '2012-Mower County',
#  '2013-Mower County',
#  '2014-Mower County',
#  '2015-Mower County',
#  '2022-Freeborn County',
#  '2022-Big Stone County',
#  '2016-Houston County',
#  '2017-Houston County',
#  '2018-Houston County',
#  '2019-Houston County',
#  '2020-Houston County',
#  '2021-Houston County',
#  '2022-Houston County',
#  '2006-Houston County',
#  '2007-Houston County',
#  '2008-Houston County',
#  '2009-Houston County',
#  '2010-Houston County',
#  '2011-Houston County',
#  '2012-Houston County',
#  '2013-Houston County',
#  '2014-Houston County',
#  '2015-Houston County',
#  '2022-Clay County',
#  '2018-Mahnomen County',
#  '2019-Mahnomen County',
#  '2022-Mahnomen County',
#  '2008-Mahnomen County',
#  '2011-Mahnomen County',
#  '2012-Mahnomen County',
#  '2022-Jackson County',
#  '1940-Benton County',
#  '1941-Benton County',
#  '1942-Benton County',
#  '1943-Benton County',
#  '1944-Benton County',
#  '1945-Benton County',
#  '1946-Benton County',
#  '1947-Benton County',
#  '1948-Benton County',
#  '1949-Benton County',
#  '1957-Benton County',
#  '1958-Benton County',
#  '2022-Benton County',
#  '2016-Fillmore County',
#  '2017-Fillmore County',
#  '2018-Fillmore County',
#  '2019-Fillmore County',
#  '2020-Fillmore County',
#  '2021-Fillmore County',
#  '2022-Fillmore County',
#  '2006-Fillmore County',
#  '2007-Fillmore County',
#  '2008-Fillmore County',
#  '2012-Fillmore County',
#  '2014-Fillmore County',
#  '2015-Fillmore County',
#  '2016-Wabasha County',
#  '2017-Wabasha County',
#  '2018-Wabasha County',
#  '2019-Wabasha County',
#  '2020-Wabasha County',
#  '2021-Wabasha County',
#  '2022-Wabasha County',
#  '2006-Wabasha County',
#  '2007-Wabasha County',
#  '2008-Wabasha County',
#  '2009-Wabasha County',
#  '2010-Wabasha County',
#  '2011-Wabasha County',
#  '2012-Wabasha County',
#  '2013-Wabasha County',
#  '2014-Wabasha County',
#  '2015-Wabasha County',
#  '2020-Chippewa County',
#  '2022-Chippewa County',
#  '2016-Lac qui Parle County',
#  '2017-Lac qui Parle County',
#  '2018-Lac qui Parle County',
#  '2019-Lac qui Parle County',
#  '2020-Lac qui Parle County',
#  '2021-Lac qui Parle County',
#  '2022-Lac qui Parle County',
#  '2006-Lac qui Parle County',
#  '2007-Lac qui Parle County',
#  '2008-Lac qui Parle County',
#  '2009-Lac qui Parle County',
#  '2010-Lac qui Parle County',
#  '2011-Lac qui Parle County',
#  '2012-Lac qui Parle County',
#  '2013-Lac qui Parle County',
#  '2014-Lac qui Parle County',
#  '2015-Lac qui Parle County',
#  '2006-Hubbard County',
#  '2007-Hubbard County',
#  '2008-Hubbard County',
#  '2009-Hubbard County',
#  '2010-Hubbard County',
#  '2011-Hubbard County',
#  '2012-Hubbard County',
#  '2014-Hubbard County',
#  '2017-Hubbard County',
#  '2018-Hubbard County',
#  '2019-Hubbard County',
#  '2022-Hubbard County',
#  '1998-Lake of the Woods County',
#  '1999-Lake of the Woods County',
#  '2000-Lake of the Woods County',
#  '2001-Lake of the Woods County',
#  '2004-Lake of the Woods County',
#  '2005-Lake of the Woods County',
#  '2006-Lake of the Woods County',
#  '2007-Lake of the Woods County',
#  '2008-Lake of the Woods County',
#  '2009-Lake of the Woods County',
#  '2010-Lake of the Woods County',
#  '2011-Lake of the Woods County',
#  '2012-Lake of the Woods County',
#  '2013-Lake of the Woods County',
#  '2014-Lake of the Woods County',
#  '2015-Lake of the Woods County',
#  '2016-Lake of the Woods County',
#  '2017-Lake of the Woods County',
#  '2018-Lake of the Woods County',
#  '2019-Lake of the Woods County',
#  '2020-Lake of the Woods County',
#  '2021-Lake of the Woods County',
#  '2022-Lake of the Woods County',
#  '2016-Dakota County',
#  '2017-Dakota County',
#  '2018-Dakota County',
#  '2019-Dakota County',
#  '2020-Dakota County',
#  '2021-Dakota County',
#  '2022-Dakota County',
#  '2006-Dakota County',
#  '2007-Dakota County',
#  '2008-Dakota County',
#  '2009-Dakota County',
#  '2010-Dakota County',
#  '2011-Dakota County',
#  '2012-Dakota County',
#  '2013-Dakota County',
#  '2014-Dakota County',
#  '2015-Dakota County',
#  '2018-Red Lake County',
#  '2019-Red Lake County',
#  '2022-Red Lake County',
#  '2014-Red Lake County',
#  '2015-Red Lake County',
#  '1999-Ramsey County',
#  '2004-Ramsey County',
#  '2005-Ramsey County',
#  '2006-Ramsey County',
#  '2007-Ramsey County',
#  '2008-Ramsey County',
#  '2009-Ramsey County',
#  '2010-Ramsey County',
#  '2011-Ramsey County',
#  '2012-Ramsey County',
#  '2013-Ramsey County',
#  '2014-Ramsey County',
#  '2015-Ramsey County',
#  '2016-Ramsey County',
#  '2017-Ramsey County',
#  '2018-Ramsey County',
#  '2019-Ramsey County',
#  '2020-Ramsey County',
#  '2021-Ramsey County',
#  '2022-Ramsey County',
#  '2018-Marshall County',
#  '2022-Marshall County',
#  '1896-Clearwater County',
#  '1897-Clearwater County',
#  '1899-Clearwater County',
#  '1900-Clearwater County',
#  '1901-Clearwater County',
#  '1902-Clearwater County',
#  '1903-Clearwater County',
#  '1904-Clearwater County',
#  '1905-Clearwater County',
#  '1906-Clearwater County',
#  '1912-Clearwater County',
#  '1913-Clearwater County',
#  '1914-Clearwater County',
#  '1915-Clearwater County',
#  '1916-Clearwater County',
#  '1917-Clearwater County',
#  '1918-Clearwater County',
#  '1919-Clearwater County',
#  '1920-Clearwater County',
#  '1922-Clearwater County',
#  '1923-Clearwater County',
#  '1924-Clearwater County',
#  '1925-Clearwater County',
#  '1926-Clearwater County',
#  '1927-Clearwater County',
#  '1928-Clearwater County',
#  '1929-Clearwater County',
#  '1930-Clearwater County',
#  '1931-Clearwater County',
#  '1932-Clearwater County',
#  '1933-Clearwater County',
#  '1934-Clearwater County',
#  '1935-Clearwater County',
#  '1936-Clearwater County',
#  '1937-Clearwater County',
#  '1938-Clearwater County',
#  '1939-Clearwater County',
#  '1940-Clearwater County',
#  '1941-Clearwater County',
#  '1942-Clearwater County',
#  '1943-Clearwater County',
#  '1944-Clearwater County',
#  '1945-Clearwater County',
#  '1946-Clearwater County',
#  '1947-Clearwater County',
#  '1948-Clearwater County',
#  '1949-Clearwater County',
#  '1957-Clearwater County',
#  '1958-Clearwater County',
#  '1959-Clearwater County',
#  '2004-Clearwater County',
#  '2009-Clearwater County',
#  '2013-Clearwater County',
#  '2014-Clearwater County',
#  '2015-Clearwater County',
#  '2016-Clearwater County',
#  '2017-Clearwater County',
#  '2018-Clearwater County',
#  '2022-Clearwater County',
#  '2022-Blue Earth County',
#  '2018-Kanabec County',
#  '2019-Kanabec County',
#  '2020-Kanabec County',
#  '2022-Kanabec County',
#  '2013-Kanabec County',
#  '2018-Pipestone County',
#  '2022-Pipestone County',
#  '2022-Faribault County',
#  '2022-Martin County',
#  '2016-Itasca County',
#  '2017-Itasca County',
#  '2018-Itasca County',
#  '2019-Itasca County',
#  '2022-Itasca County',
#  '2006-Itasca County',
#  '2007-Itasca County',
#  '2008-Itasca County',
#  '2009-Itasca County',
#  '2010-Itasca County',
#  '2011-Itasca County',
#  '2012-Itasca County',
#  '2013-Itasca County',
#  '2014-Itasca County',
#  '2015-Itasca County',
#  '2016-Goodhue County',
#  '2017-Goodhue County',
#  '2018-Goodhue County',
#  '2019-Goodhue County',
#  '2020-Goodhue County',
#  '2021-Goodhue County',
#  '2022-Goodhue County',
#  '2006-Goodhue County',
#  '2007-Goodhue County',
#  '2008-Goodhue County',
#  '2009-Goodhue County',
#  '2010-Goodhue County',
#  '2011-Goodhue County',
#  '2012-Goodhue County',
#  '2013-Goodhue County',
#  '2014-Goodhue County',
#  '2015-Goodhue County',
#  '2021-Kittson County',
#  '2022-Kittson County',
#  '2009-Kittson County',
#  '2010-Kittson County',
#  '2011-Kittson County',
#  '2013-Kittson County',
#  '2014-Kittson County',
#  '2015-Kittson County',
#  '2018-Meeker County',
#  '2022-Meeker County',
#  '2016-Pine County',
#  '2017-Pine County',
#  '2022-Pine County',
#  '1893-Olmsted County',
#  '1909-Olmsted County',
#  '1910-Olmsted County',
#  '1911-Olmsted County',
#  '1912-Olmsted County',
#  '1913-Olmsted County',
#  '1914-Olmsted County',
#  '1915-Olmsted County',
#  '1916-Olmsted County',
#  '1917-Olmsted County',
#  '1918-Olmsted County',
#  '1919-Olmsted County',
#  '1920-Olmsted County',
#  '1929-Olmsted County',
#  '1930-Olmsted County',
#  '1931-Olmsted County',
#  '1932-Olmsted County',
#  '1933-Olmsted County',
#  '1934-Olmsted County',
#  '1935-Olmsted County',
#  '1936-Olmsted County',
#  '1937-Olmsted County',
#  '1938-Olmsted County',
#  '1939-Olmsted County',
#  '1940-Olmsted County',
#  '1941-Olmsted County',
#  '1942-Olmsted County',
#  '1943-Olmsted County',
#  '1944-Olmsted County',
#  '1945-Olmsted County',
#  '1946-Olmsted County',
#  '1947-Olmsted County',
#  '1948-Olmsted County',
#  '1949-Olmsted County',
#  '1950-Olmsted County',
#  '1951-Olmsted County',
#  '1952-Olmsted County',
#  '1953-Olmsted County',
#  '1954-Olmsted County',
#  '1955-Olmsted County',
#  '1956-Olmsted County',
#  '1957-Olmsted County',
#  '1958-Olmsted County',
#  '1959-Olmsted County',
#  '1960-Olmsted County',
#  '1961-Olmsted County',
#  '1962-Olmsted County',
#  '1963-Olmsted County',
#  '1964-Olmsted County',
#  '1965-Olmsted County',
#  '1966-Olmsted County',
#  '1967-Olmsted County',
#  '1968-Olmsted County',
#  '1969-Olmsted County',
#  '1970-Olmsted County',
#  '1971-Olmsted County',
#  '1972-Olmsted County',
#  '1973-Olmsted County',
#  '1974-Olmsted County',
#  '1975-Olmsted County',
#  '1976-Olmsted County',
#  '1977-Olmsted County',
#  '1978-Olmsted County',
#  '1979-Olmsted County',
#  '1980-Olmsted County',
#  '1981-Olmsted County',
#  '1982-Olmsted County',
#  '1983-Olmsted County',
#  '1984-Olmsted County',
#  '1985-Olmsted County',
#  '1986-Olmsted County',
#  '1987-Olmsted County',
#  '1988-Olmsted County',
#  '1989-Olmsted County',
#  '1990-Olmsted County',
#  '1991-Olmsted County',
#  '1992-Olmsted County',
#  '1993-Olmsted County',
#  '1994-Olmsted County',
#  '1995-Olmsted County',
#  '1996-Olmsted County',
#  '1997-Olmsted County',
#  '1998-Olmsted County',
#  '1999-Olmsted County',
#  '2000-Olmsted County',
#  '2001-Olmsted County',
#  '2002-Olmsted County',
#  '2003-Olmsted County',
#  '2004-Olmsted County',
#  '2005-Olmsted County',
#  '2006-Olmsted County',
#  '2007-Olmsted County',
#  '2008-Olmsted County',
#  '2009-Olmsted County',
#  '2010-Olmsted County',
#  '2011-Olmsted County',
#  '2012-Olmsted County',
#  '2013-Olmsted County',
#  '2014-Olmsted County',
#  '2015-Olmsted County',
#  '2016-Olmsted County',
#  '2017-Olmsted County',
#  '2018-Olmsted County',
#  '2019-Olmsted County',
#  '2020-Olmsted County',
#  '2021-Olmsted County',
#  '2022-Olmsted County',
#  '2022-Stevens County',
#  '2022-Murray County',
#  '2018-Lincoln County',
#  '2022-Lincoln County',
#  '2022-Todd County',
#  '2019-Carlton County',
#  '2020-Carlton County',
#  '2021-Carlton County',
#  '2022-Carlton County',
#  '2006-Carlton County',
#  '2007-Carlton County',
#  '2008-Carlton County',
#  '2009-Carlton County',
#  '2011-Carlton County',
#  '2014-Carlton County',
#  '2015-Carlton County',
#  '2017-Cass County',
#  '2018-Cass County',
#  '2019-Cass County',
#  '2021-Cass County',
#  '2022-Cass County',
#  '2006-Cass County',
#  '2007-Cass County',
#  '2008-Cass County',
#  '2009-Cass County',
#  '2010-Cass County',
#  '2011-Cass County',
#  '2012-Cass County',
#  '2013-Cass County',
#  '2014-Cass County',
#  '2015-Cass County',
#  '1908-Koochiching County',
#  '1909-Koochiching County',
#  '1910-Koochiching County',
#  '1911-Koochiching County',
#  '1912-Koochiching County',
#  '1913-Koochiching County',
#  '1914-Koochiching County',
#  '1915-Koochiching County',
#  '1916-Koochiching County',
#  '1917-Koochiching County',
#  '1918-Koochiching County',
#  '1919-Koochiching County',
#  '1920-Koochiching County',
#  '1921-Koochiching County',
#  '1922-Koochiching County',
#  '1923-Koochiching County',
#  '1924-Koochiching County',
#  '1925-Koochiching County',
#  '1926-Koochiching County',
#  '1948-Koochiching County',
#  '1949-Koochiching County',
#  '1957-Koochiching County',
#  '1958-Koochiching County',
#  '1959-Koochiching County',
#  '1960-Koochiching County',
#  '1961-Koochiching County',
#  '1962-Koochiching County',
#  '1963-Koochiching County',
#  '1964-Koochiching County',
#  '1965-Koochiching County',
#  '1967-Koochiching County',
#  '1968-Koochiching County',
#  '1969-Koochiching County',
#  '1970-Koochiching County',
#  '1971-Koochiching County',
#  '1975-Koochiching County',
#  '1976-Koochiching County',
#  '1981-Koochiching County',
#  '1987-Koochiching County',
#  '1989-Koochiching County',
#  '1990-Koochiching County',
#  '1993-Koochiching County',
#  '1994-Koochiching County',
#  '1995-Koochiching County',
#  '1996-Koochiching County',
#  '1997-Koochiching County',
#  '1998-Koochiching County',
#  '1999-Koochiching County',
#  '2000-Koochiching County',
#  '2001-Koochiching County',
#  '2002-Koochiching County',
#  '2003-Koochiching County',
#  '2004-Koochiching County',
#  '2005-Koochiching County',
#  '2006-Koochiching County',
#  '2007-Koochiching County',
#  '2008-Koochiching County',
#  '2009-Koochiching County',
#  '2010-Koochiching County',
#  '2011-Koochiching County',
#  '2012-Koochiching County',
#  '2014-Koochiching County',
#  '2015-Koochiching County',
#  '2016-Koochiching County',
#  '2017-Koochiching County',
#  '2018-Koochiching County',
#  '2019-Koochiching County',
#  '2020-Koochiching County',
#  '2021-Koochiching County',
#  '2022-Koochiching County',
#  '2022-Washington County',
#  '2016-McLeod County',
#  '2017-McLeod County',
#  '2018-McLeod County',
#  '2019-McLeod County',
#  '2020-McLeod County',
#  '2021-McLeod County',
#  '2022-McLeod County',
#  '2006-McLeod County',
#  '2007-McLeod County',
#  '2008-McLeod County',
#  '2009-McLeod County',
#  '2010-McLeod County',
#  '2011-McLeod County',
#  '2012-McLeod County',
#  '2013-McLeod County',
#  '2014-McLeod County',
#  '2015-McLeod County',
#  '2019-Rice County',
#  '2022-Rice County']

# %%
final_dataframe['Corn_Yield'] = y.loc[common]['BU / ACRE']

# %%
final_dataframe[final_dataframe['Corn_Yield'].notna()]
# Out:
#                     01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 1993-Pope County   -23.500000     -28.90 -16.700000         NaN        NaN
# 1999-Pope County   -19.300000     -23.00 -16.000000         NaN -12.900000
# 2000-Pope County    -5.400000      -7.80  -2.800000         NaN  -3.800000
# 2001-Pope County   -21.200000     -26.70 -15.000000         NaN -12.100000
# 2002-Pope County   -15.000000     -18.90 -12.800000         NaN -17.300000
# ...                       ...        ...        ...         ...        ...
# 2011-Waseca County -16.200000     -18.50 -14.500000         NaN -12.700000
# 2012-Waseca County  -3.166667      -7.00   1.000000         NaN  -9.050000
# 2013-Waseca County -15.025000     -23.25  -7.500000         NaN  -8.475000
# 2014-Waseca County -18.400000     -21.00 -16.333333         NaN -20.933333
# 2015-Waseca County  -6.333333     -13.00  -0.666667         NaN  -7.300000
#
#                     01-02-min  01-02-max  01-02-prec  01-03-avg  01-03-min  \
# 1993-Pope County          NaN        NaN         NaN  -9.300000 -17.800000
# 1999-Pope County   -16.000000     -11.00         NaN        NaN        NaN
# 2000-Pope County    -5.600000      -2.80         NaN  -5.800000 -13.900000
# 2001-Pope County   -18.900000      -5.00         NaN  -4.800000  -5.600000
# 2002-Pope County   -21.700000     -12.80         NaN  -9.500000 -15.000000
# ...                       ...        ...         ...        ...        ...
# 2011-Waseca County -19.000000      -6.00         NaN  -8.200000 -17.000000
# 2012-Waseca County -14.000000      -6.50         NaN  -6.633333 -12.666667
# 2013-Waseca County -12.000000      -3.25         NaN -10.750000 -13.500000
# 2014-Waseca County -26.666667     -17.00         NaN -12.166667 -26.333333
# 2015-Waseca County -14.500000      -2.75         NaN  -3.466667  -9.666667
#
#                     ...  09-27-prec  09-28-avg  09-28-min  09-28-max  \
# 1993-Pope County    ...         NaN        NaN        NaN        NaN
# 1999-Pope County    ...         NaN   8.700000   3.900000  13.900000
# 2000-Pope County    ...         NaN  14.500000   3.300000  27.200000
# 2001-Pope County    ...         NaN  12.800000   6.100000  20.600000
# 2002-Pope County    ...         NaN   9.200000   6.700000  11.100000
# ...                 ...         ...        ...        ...        ...
# 2011-Waseca County  ...         NaN  17.725000  11.250000  26.250000
# 2012-Waseca County  ...         NaN  14.033333   4.666667  24.666667
# 2013-Waseca County  ...         NaN  16.200000   8.666667  22.000000
# 2014-Waseca County  ...         NaN  19.566667  12.666667  26.666667
# 2015-Waseca County  ...         NaN  19.825000  16.000000  24.000000
#
#                     09-28-prec  09-30-avg  09-30-min  09-30-max  09-30-prec  \
# 1993-Pope County           NaN  12.000000   5.000000  21.100000         NaN
# 1999-Pope County           NaN   8.800000   5.000000  12.200000         NaN
# 2000-Pope County           NaN  16.700000   7.800000  26.700000         NaN
# 2001-Pope County           NaN  16.000000  11.100000  22.800000         NaN
# 2002-Pope County           NaN  17.600000  12.200000  26.700000         NaN
# ...                        ...        ...        ...        ...         ...
# 2011-Waseca County         NaN  11.900000   6.750000  17.000000         NaN
# 2012-Waseca County         NaN  16.533333   6.666667  26.666667         NaN
# 2013-Waseca County         NaN  18.500000  12.333333  25.666667         NaN
# 2014-Waseca County         NaN  10.300000   5.750000  16.000000         NaN
# 2015-Waseca County         NaN  10.666667   4.666667  17.000000         NaN
#
#                     Corn_Yield
# 1993-Pope County          58.0
# 1999-Pope County         151.0
# 2000-Pope County         153.0
# 2001-Pope County         138.0
# 2002-Pope County         164.0
# ...                        ...
# 2011-Waseca County       175.9
# 2012-Waseca County       180.1
# 2013-Waseca County       171.6
# 2014-Waseca County       160.2
# 2015-Waseca County       199.2
#
# [1449 rows x 889 columns]

# %%
united_data = final_dataframe[final_dataframe['Corn_Yield'].notna()]

# %%
united_data
# Out:
#                     01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 1993-Pope County   -23.500000     -28.90 -16.700000         NaN        NaN
# 1999-Pope County   -19.300000     -23.00 -16.000000         NaN -12.900000
# 2000-Pope County    -5.400000      -7.80  -2.800000         NaN  -3.800000
# 2001-Pope County   -21.200000     -26.70 -15.000000         NaN -12.100000
# 2002-Pope County   -15.000000     -18.90 -12.800000         NaN -17.300000
# ...                       ...        ...        ...         ...        ...
# 2011-Waseca County -16.200000     -18.50 -14.500000         NaN -12.700000
# 2012-Waseca County  -3.166667      -7.00   1.000000         NaN  -9.050000
# 2013-Waseca County -15.025000     -23.25  -7.500000         NaN  -8.475000
# 2014-Waseca County -18.400000     -21.00 -16.333333         NaN -20.933333
# 2015-Waseca County  -6.333333     -13.00  -0.666667         NaN  -7.300000
#
#                     01-02-min  01-02-max  01-02-prec  01-03-avg  01-03-min  \
# 1993-Pope County          NaN        NaN         NaN  -9.300000 -17.800000
# 1999-Pope County   -16.000000     -11.00         NaN        NaN        NaN
# 2000-Pope County    -5.600000      -2.80         NaN  -5.800000 -13.900000
# 2001-Pope County   -18.900000      -5.00         NaN  -4.800000  -5.600000
# 2002-Pope County   -21.700000     -12.80         NaN  -9.500000 -15.000000
# ...                       ...        ...         ...        ...        ...
# 2011-Waseca County -19.000000      -6.00         NaN  -8.200000 -17.000000
# 2012-Waseca County -14.000000      -6.50         NaN  -6.633333 -12.666667
# 2013-Waseca County -12.000000      -3.25         NaN -10.750000 -13.500000
# 2014-Waseca County -26.666667     -17.00         NaN -12.166667 -26.333333
# 2015-Waseca County -14.500000      -2.75         NaN  -3.466667  -9.666667
#
#                     ...  09-27-prec  09-28-avg  09-28-min  09-28-max  \
# 1993-Pope County    ...         NaN        NaN        NaN        NaN
# 1999-Pope County    ...         NaN   8.700000   3.900000  13.900000
# 2000-Pope County    ...         NaN  14.500000   3.300000  27.200000
# 2001-Pope County    ...         NaN  12.800000   6.100000  20.600000
# 2002-Pope County    ...         NaN   9.200000   6.700000  11.100000
# ...                 ...         ...        ...        ...        ...
# 2011-Waseca County  ...         NaN  17.725000  11.250000  26.250000
# 2012-Waseca County  ...         NaN  14.033333   4.666667  24.666667
# 2013-Waseca County  ...         NaN  16.200000   8.666667  22.000000
# 2014-Waseca County  ...         NaN  19.566667  12.666667  26.666667
# 2015-Waseca County  ...         NaN  19.825000  16.000000  24.000000
#
#                     09-28-prec  09-30-avg  09-30-min  09-30-max  09-30-prec  \
# 1993-Pope County           NaN  12.000000   5.000000  21.100000         NaN
# 1999-Pope County           NaN   8.800000   5.000000  12.200000         NaN
# 2000-Pope County           NaN  16.700000   7.800000  26.700000         NaN
# 2001-Pope County           NaN  16.000000  11.100000  22.800000         NaN
# 2002-Pope County           NaN  17.600000  12.200000  26.700000         NaN
# ...                        ...        ...        ...        ...         ...
# 2011-Waseca County         NaN  11.900000   6.750000  17.000000         NaN
# 2012-Waseca County         NaN  16.533333   6.666667  26.666667         NaN
# 2013-Waseca County         NaN  18.500000  12.333333  25.666667         NaN
# 2014-Waseca County         NaN  10.300000   5.750000  16.000000         NaN
# 2015-Waseca County         NaN  10.666667   4.666667  17.000000         NaN
#
#                     Corn_Yield
# 1993-Pope County          58.0
# 1999-Pope County         151.0
# 2000-Pope County         153.0
# 2001-Pope County         138.0
# 2002-Pope County         164.0
# ...                        ...
# 2011-Waseca County       175.9
# 2012-Waseca County       180.1
# 2013-Waseca County       171.6
# 2014-Waseca County       160.2
# 2015-Waseca County       199.2
#
# [1449 rows x 889 columns]

# %%
united_data.to_csv('united_data.csv')
