# %%
import pandas as pd
import numpy as np
import tqdm
from utils import get_data_from_station, get_stations, unite_stations, columns, county_names, dates, metrics, fill_missing

# %%
final_dataframe = pd.read_csv('final_data_nonnull.csv', index_col=0)

# %%
final_dataframe
# Out:
#                       01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 2016-Pope County           -7.7      -12.0       -4.0         NaN       -7.4
# 2017-Pope County           -5.7       -9.0       -4.0         NaN       -4.7
# 2018-Pope County          -24.3      -28.0      -19.0         NaN      -17.9
# 2019-Pope County            NaN        NaN        NaN         NaN      -12.1
# 2020-Pope County            NaN        NaN        NaN         NaN        NaN
# ...                         ...        ...        ...         ...        ...
# 2011-Watonwan County      -15.5      -18.0      -13.0         NaN      -12.5
# 2012-Watonwan County       -2.4       -6.0        2.0         NaN       -8.5
# 2013-Watonwan County      -11.0      -19.0       -4.0         NaN       -4.9
# 2014-Watonwan County      -19.2      -21.0      -18.0         NaN      -23.9
# 2015-Watonwan County       -5.5      -12.0        1.0         NaN       -5.7
#
# ...

# %%
y = pd.read_csv('..\data\oats_data.csv', index_col=0)

# %%
y
# Out:
#                                County  YIELD, MEASURED IN BU / ACRE
# index
# 1950-Aitkin County      Aitkin County                          27.0
# 1950-Anoka County        Anoka County                          28.0
# 1950-Becker County      Becker County                          34.0
# 1950-Beltrami County  Beltrami County                          36.0
# 1950-Benton County      Benton County                          20.0
# ...                               ...                           ...
# 2021-Steele County      Steele County                          81.2
# 2021-Swift County        Swift County                          68.7
# 2021-Todd County          Todd County                          36.6
# 2021-Watonwan County  Watonwan County                          58.1
# 2021-Wright County      Wright County                          48.6
#
# [4904 rows x 2 columns]

# %%
X = final_dataframe

# %%
y_index = y.index.to_list()
x_index = X.index.to_list()

common = []
for t in x_index:
    if t in y_index:
        common.append(t)
        
len(common)
# Out:
# 964

# %%
final_dataframe['Oat_Yield'] = y.loc[common]['YIELD, MEASURED IN BU / ACRE']

# %%
final_dataframe[final_dataframe['Oat_Yield'].notna()]
# Out:
#                       01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 2016-Pope County           -7.7      -12.0       -4.0         NaN       -7.4
# 2021-Pope County           -9.7      -14.0       -6.0         NaN       -4.9
# 2006-Pope County           -3.2       -4.0       -2.0         NaN       -0.6
# 2010-Pope County          -23.0      -29.0      -19.0         NaN      -26.8
# 2011-Pope County          -16.8      -18.0      -14.0         NaN      -17.4
# ...                         ...        ...        ...         ...        ...
# 2020-Hubbard County        -7.9      -15.0       -1.1         0.0       -2.7
# 2019-Watonwan County        NaN        NaN        NaN         NaN       -9.2
# 2020-Watonwan County        NaN        NaN        NaN         NaN        NaN
# 2021-Watonwan County       -9.4      -12.0       -6.0         NaN       -7.4
# 2011-Watonwan County      -15.5      -18.0      -13.0         NaN      -12.5
#
# ...

# %%
united_data = final_dataframe[final_dataframe['Oat_Yield'].notna()]

# %%
united_data
# Out:
#                       01-01-avg  01-01-min  01-01-max  01-01-prec  01-02-avg  \
# 2016-Pope County           -7.7      -12.0       -4.0         NaN       -7.4
# 2021-Pope County           -9.7      -14.0       -6.0         NaN       -4.9
# 2006-Pope County           -3.2       -4.0       -2.0         NaN       -0.6
# 2010-Pope County          -23.0      -29.0      -19.0         NaN      -26.8
# 2011-Pope County          -16.8      -18.0      -14.0         NaN      -17.4
# ...                         ...        ...        ...         ...        ...
# 2020-Hubbard County        -7.9      -15.0       -1.1         0.0       -2.7
# 2019-Watonwan County        NaN        NaN        NaN         NaN       -9.2
# 2020-Watonwan County        NaN        NaN        NaN         NaN        NaN
# 2021-Watonwan County       -9.4      -12.0       -6.0         NaN       -7.4
# 2011-Watonwan County      -15.5      -18.0      -13.0         NaN      -12.5
#
# ...

# %%
united_data.to_csv('../data/united_oats.csv')
